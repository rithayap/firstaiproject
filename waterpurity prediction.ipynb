# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("D:\dataset\supervised\water_potability.csv")
data
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
print(data.describe())
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# ...

# %%
print(data.shape)
# Out:
# (3276, 10)

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB
# None

# %%
print(data.isna().sum())
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
num_cols=data.select_dtypes(include="number").columns
data[num_cols]=data[num_cols].fillna(data[num_cols].mean())

# %%
print(data.isna().sum())
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %%
data.corr()
# Out:
#                        ph  Hardness    Solids  Chloramines   Sulfate  \
# ph               1.000000  0.075833 -0.081884    -0.031811  0.014403
# Hardness         0.075833  1.000000 -0.046899    -0.030054 -0.092766
# Solids          -0.081884 -0.046899  1.000000    -0.070148 -0.149840
# Chloramines     -0.031811 -0.030054 -0.070148     1.000000  0.023791
# Sulfate          0.014403 -0.092766 -0.149840     0.023791  1.000000
# Conductivity     0.017192 -0.023915  0.013831    -0.020486 -0.014059
# Organic_carbon   0.040061  0.003610  0.010242    -0.012653  0.026909
# Trihalomethanes  0.002994 -0.012690 -0.008875     0.016627 -0.025605
# Turbidity       -0.036222 -0.014449  0.019546     0.002363 -0.009790
# Potability      -0.003287 -0.013837  0.033743     0.023779 -0.020619
#
#                  Conductivity  Organic_carbon  Trihalomethanes  Turbidity  \
# ph                   0.017192        0.040061         0.002994  -0.036222
# ...

# %%
sns.heatmap(data.corr(),annot=True,cmap="viridis")
plt.figure(figsize=(10,6))

# %%
sns.countplot(x="Potability",data=data)
# Out:
# <Axes: xlabel='Potability', ylabel='count'>

# %%
sns.pairplot(data)
plt.show()

# %%
# from scipy import stats
# num_cols=data.select_dtypes(include="number")

# z_score=np.abs(stats.zscore(num_cols))
# threshold=3

# outliers_z=z_score>3
# outliers=data[(outliers_z).any(axis=1)]
# print("size before removing outliers",data.shape)

# no_outliers=data[(z_score<3).all(axis=1)]
# print("size after removing outliers",no_outliers.shape)

# %%
x=data.iloc[:,:-1]
x
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0     7.080795  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246  333.775777
# 2     8.099124  224.236259  19909.541732     9.275884  333.775777
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362  333.775777
# 3273  9.419510  175.762646  33155.578218     7.350233  333.775777
# 3274  5.126763  230.603758  11983.869376     6.303357  333.775777
# 3275  7.874671  195.102299  17404.177061     7.509306  333.775777
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# 0       564.308654       10.379783        86.990970   2.963135
# ...

# %%
y=data.loc[:,"Potability"]
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3271    1
# 3272    1
# 3273    1
# 3274    1
# 3275    1
# Name: Potability, Length: 3276, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
x_train
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 233   6.623614  203.030141  17167.301297     6.049601  311.726288
# 831   6.684700  193.840931  34157.184474     9.876574  344.535407
# 2658  6.836060  205.667718  18321.327502     6.712854  297.837188
# 2495  7.080795  183.488839  12675.938962     9.777807  319.870584
# 2603  6.406798  182.885137  17851.064021     7.462758  332.486731
# ...        ...         ...           ...          ...         ...
# 1095  4.187491  208.374188  21809.709834     5.846112  327.474203
# 1130  7.793915  164.958947  25506.912237     7.868036  358.259200
# 1294  6.630364  186.761088  30939.023214     7.703481  333.775777
# 860   8.783168  218.032840  16183.586649     7.390474  334.053885
# 3174  6.698154  198.286268  34675.862845     6.263602  360.232834
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# 233     410.243247       15.914500        65.021229   2.915166
# ...

# %%
y_train
# Out:
# 233     0
# 831     0
# 2658    0
# 2495    0
# 2603    0
#        ..
# 1095    1
# 1130    1
# 1294    0
# 860     0
# 3174    1
# Name: Potability, Length: 2620, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train)
x_train=scaler.transform(x_train)
x_test=scaler.transform(x_test)
print(x_train.shape)
# Out:
# (2620, 9)

# %%
x_test.shape
# Out:
# (656, 9)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

# %%
k_model=KNeighborsClassifier(n_neighbors=7)
nb_model=GaussianNB()
rf_model=RandomForestClassifier(n_estimators=300)
sv_model=SVC()
dt_model=DecisionTreeClassifier()
lr_model=LogisticRegression()

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
models=[k_model,nb_model,rf_model,sv_model,dt_model,lr_model]
accuracy=[]
for model in models:
    print(model)
    print()
    model.fit(x_train,y_train)
    y_predict=model.predict(x_test)
    y_predict
    acc=accuracy_score(y_test,y_predict)
    accuracy.append(acc)
    print(acc)
    print(classification_report(y_test,y_predict))
    print(confusion_matrix(y_test,y_predict))
# Out:
# KNeighborsClassifier(n_neighbors=7)
#
# 0.6310975609756098
#               precision    recall  f1-score   support
#
#            0       0.68      0.78      0.73       412
#            1       0.51      0.37      0.43       244
#
#     accuracy                           0.63       656
#    macro avg       0.59      0.58      0.58       656
# weighted avg       0.61      0.63      0.62       656
#
# [[323  89]
#  [153  91]]
# GaussianNB()
#
# 0.6310975609756098
#               precision    recall  f1-score   support
#
#            0       0.65      0.88      0.75       412
#            1       0.51      0.22      0.30       244
#
#     accuracy                           0.63       656
#    macro avg       0.58      0.55      0.53       656
# weighted avg       0.60      0.63      0.58       656
#
# [[361  51]
#  [191  53]]
# RandomForestClassifier(n_estimators=300)
#
# 0.6798780487804879
#               precision    recall  f1-score   support
#
# ...

# %%
print(accuracy)
models=['k_model','nb_model','rf_model','sv_model','dt_model','lr_model']
print(models)
# Out:
# [0.6310975609756098, 0.6310975609756098, 0.6798780487804879, 0.6951219512195121, 0.5838414634146342, 0.6280487804878049]
# ['k_model', 'nb_model', 'rf_model', 'sv_model', 'dt_model', 'lr_model']

# %%
d={'model':models,'Accuracy_score':accuracy}
df=pd.DataFrame(d)
df
# Out:
#       model  Accuracy_score
# 0   k_model        0.631098
# 1  nb_model        0.631098
# 2  rf_model        0.679878
# 3  sv_model        0.695122
# 4  dt_model        0.583841
# 5  lr_model        0.628049

# %%
plt.bar(models,accuracy)
plt.show()

# %%
from sklearn.model_selection import RandomizedSearchCV
KN1=KNeighborsClassifier()
parameter={"n_neighbors":[3,5,7,9],"weights":["uniform","distance"],"metric":["euclidean","manhattan"]}
kneigh=RandomizedSearchCV(KN1,parameter,cv=10,scoring='accuracy')
kneigh.fit(x_train,y_train)
print(kneigh.best_params_)
kneigh.best_score_
# Out:
# {'weights': 'distance', 'n_neighbors': 9, 'metric': 'manhattan'}
# np.float64(0.6374045801526718)

# %%
dnt=DecisionTreeClassifier()
param={'max_depth':[None,5,10,15],
       'min_samples_split':[2,5,10],
       'min_samples_leaf':[1,2,4],
       'criterion':['gini','entropy']}
dectree=RandomizedSearchCV(dnt,param,cv=10,scoring='accuracy')
dectree.fit(x_train,y_train)
print(dectree.best_params_)
dectree.best_score_
# Out:
# {'min_samples_split': 2, 'min_samples_leaf': 2, 'max_depth': 5, 'criterion': 'gini'}
# np.float64(0.6377862595419848)
